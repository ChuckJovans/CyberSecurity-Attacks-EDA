# %% [markdown]
# EDA ON CYBERSECURITY THREAT DATA SET

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Adding the data scrubber package (For a Fast way to Do Data Cleaning, Data Analysis, Data Feature Correlation)

# %%
from Datascrubber import Datacleaning
datacleaner = Datacleaning()

# %% [markdown]
# Enterning the Data Frame using Data Scrubber

# %%
datacleaner.read_data(r"C:\Users\HP\Desktop\UCU\Cyber Security\CyberSecurity-Attacks-EDA\cybersecurity_attacks.csv")
# Out:
# Data Description:
#
# The file cybersecurity_attacks has 40000 Rows and 25 Columns
#
# Categorical Columns(21): Timestamp, Source IP Address, Destination IP Address, Protocol, Packet Type, Traffic Type, Payload Data, Malware Indicators, Alerts/Warnings, Attack Type, Attack Signature, Action Taken, Severity Level, User Information, Device Information, Network Segment, Geo-location Data, Proxy Information, Firewall Logs, IDS/IPS Alerts, Log Source
# Continuous Columns(4): Source Port, Destination Port, Packet Length, Anomaly Scores
#
# Missing Values:99929
#
# Details :
# - Timestamp: 0
# - Source IP Address: 0
# - Destination IP Address: 0
# - Source Port: 0
# - Destination Port: 0
# - Protocol: 0
# - Packet Length: 0
# - Packet Type: 0
# - Traffic Type: 0
# - Payload Data: 0
# - Malware Indicators: 20000
# - Anomaly Scores: 0
# - Alerts/Warnings: 20067
# - Attack Type: 0
# - Attack Signature: 0
# - Action Taken: 0
# - Severity Level: 0
# - User Information: 0
# ...

# %%
df = datacleaner.data_cleaning()

# %%
df
# Out:
#                  Timestamp Source IP Address Destination IP Address  \
# 0      2023-05-30 06:33:58     103.216.15.12           84.9.164.252
# 1      2020-08-26 07:08:30    78.199.217.198         66.191.137.154
# 2      2022-11-13 08:23:25      63.79.210.48          198.219.82.17
# 3      2023-07-02 10:38:46     163.42.196.10        101.228.192.255
# 4      2023-07-16 13:11:07     71.166.185.76        189.243.174.238
# ...                    ...               ...                    ...
# 39995  2023-05-26 14:08:42      26.36.109.26         121.100.75.240
# 39996  2023-03-27 00:38:27      17.21.163.81         196.108.134.78
# 39997  2022-03-31 01:45:49     162.35.217.57            98.107.0.15
# 39998  2023-09-22 18:32:38    208.72.233.205         173.79.112.252
# 39999  2023-10-10 11:59:52     14.102.21.108           109.198.45.7
#
#        Source Port  Destination Port Protocol  Packet Length Packet Type  \
# 0          31225.0           17616.0     ICMP          503.0        Data
# ...

# %%
df.isnull().sum()
# Out:
# Timestamp                 0
# Source IP Address         0
# Destination IP Address    0
# Source Port               0
# Destination Port          0
# Protocol                  0
# Packet Length             0
# Packet Type               0
# Traffic Type              0
# Payload Data              0
# Malware Indicators        0
# Anomaly Scores            0
# Alerts/Warnings           0
# Attack Type               0
# Attack Signature          0
# Action Taken              0
# Severity Level            0
# User Information          0
# Device Information        0
# Network Segment           0
# Geo-location Data         0
# Proxy Information         0
# Firewall Logs             0
# IDS/IPS Alerts            0
# Log Source                0
# dtype: int64

# %% [markdown]
# Saving The Cleaned Data Frame

# %%
datacleaner.savedata()
# Out:
# Cleaned data has been exported as 'cleaned_data.csv'

# %%
datacleaner.columns()
# Out:
# Index(['Timestamp', 'Source IP Address', 'Destination IP Address',
#        'Source Port', 'Destination Port', 'Protocol', 'Packet Length',
#        'Packet Type', 'Traffic Type', 'Payload Data', 'Malware Indicators',
#        'Anomaly Scores', 'Alerts/Warnings', 'Attack Type', 'Attack Signature',
#        'Action Taken', 'Severity Level', 'User Information',
#        'Device Information', 'Network Segment', 'Geo-location Data',
#        'Proxy Information', 'Firewall Logs', 'IDS/IPS Alerts', 'Log Source'],
#       dtype='object')

# %%
df
# Out:
#                  Timestamp Source IP Address Destination IP Address  \
# 0      2023-05-30 06:33:58     103.216.15.12           84.9.164.252
# 1      2020-08-26 07:08:30    78.199.217.198         66.191.137.154
# 2      2022-11-13 08:23:25      63.79.210.48          198.219.82.17
# 3      2023-07-02 10:38:46     163.42.196.10        101.228.192.255
# 4      2023-07-16 13:11:07     71.166.185.76        189.243.174.238
# ...                    ...               ...                    ...
# 39995  2023-05-26 14:08:42      26.36.109.26         121.100.75.240
# 39996  2023-03-27 00:38:27      17.21.163.81         196.108.134.78
# 39997  2022-03-31 01:45:49     162.35.217.57            98.107.0.15
# 39998  2023-09-22 18:32:38    208.72.233.205         173.79.112.252
# 39999  2023-10-10 11:59:52     14.102.21.108           109.198.45.7
#
#        Source Port  Destination Port Protocol  Packet Length Packet Type  \
# 0          31225.0           17616.0     ICMP          503.0        Data
# ...

# %% [markdown]
# Performing Statistics on the Data Frame

# %%
datacleaner.summary()
# Out:
#                   Timestamp Source IP Address Destination IP Address  \
# count                 40000             40000                  40000
# unique                39997             40000                  40000
# top     2022-06-11 14:28:15     103.216.15.12           84.9.164.252
# freq                      2                 1                      1
# mean                    NaN               NaN                    NaN
# std                     NaN               NaN                    NaN
# min                     NaN               NaN                    NaN
# 25%                     NaN               NaN                    NaN
# 50%                     NaN               NaN                    NaN
# 75%                     NaN               NaN                    NaN
# max                     NaN               NaN                    NaN
#
#          Source Port  Destination Port Protocol  Packet Length Packet Type  \
# ...

# %%
datacleaner.cont_cols()
# Out:
#    Source Port  Destination Port  Packet Length  Anomaly Scores
# 0      31225.0           17616.0          503.0           28.67
# 1      17245.0           48166.0         1174.0           51.50
# 2      16811.0           53600.0          306.0           87.42
# 3      20018.0           32534.0          385.0           15.79
# 4       6131.0           26646.0         1462.0            0.52

# %%
datacleaner.cat_cols()
# Out:
#              Timestamp Source IP Address Destination IP Address Protocol  \
# 0  2023-05-30 06:33:58     103.216.15.12           84.9.164.252     ICMP
# 1  2020-08-26 07:08:30    78.199.217.198         66.191.137.154     ICMP
# 2  2022-11-13 08:23:25      63.79.210.48          198.219.82.17      UDP
# 3  2023-07-02 10:38:46     163.42.196.10        101.228.192.255      UDP
# 4  2023-07-16 13:11:07     71.166.185.76        189.243.174.238      TCP
#
#   Packet Type Traffic Type                                       Payload Data  \
# 0        Data         HTTP  Qui natus odio asperiores nam. Optio nobis ius...
# 1        Data         HTTP  Aperiam quos modi officiis veritatis rem. Omni...
# 2     Control         HTTP  Perferendis sapiente vitae soluta. Hic delectu...
# 3        Data         HTTP  Totam maxime beatae expedita explicabo porro l...
# 4        Data          DNS  Odit nesciunt dolorem nisi iste iusto. Animi v...
#
# ...

# %%
datacleaner.missing_values()
# Out:
# Timestamp                 0
# Source IP Address         0
# Destination IP Address    0
# Source Port               0
# Destination Port          0
# Protocol                  0
# Packet Length             0
# Packet Type               0
# Traffic Type              0
# Payload Data              0
# Malware Indicators        0
# Anomaly Scores            0
# Alerts/Warnings           0
# Attack Type               0
# Attack Signature          0
# Action Taken              0
# Severity Level            0
# User Information          0
# Device Information        0
# Network Segment           0
# Geo-location Data         0
# Proxy Information         0
# Firewall Logs             0
# IDS/IPS Alerts            0
# Log Source                0
# dtype: int64

# %% [markdown]
# Looking at Distributions of the continous features

# %%
datacleaner.distributions()

# %%
datacleaner.col_cat_dist('Attack Type')

# %%
datacleaner.col_cat_dist('Protocol')

# %%
datacleaner.col_cat_dist('Traffic Type')

# %%
datacleaner.col_cat_dist('Severity Level')

# %%
datacleaner.cont_to_cont("Source Port","Anomaly Scores")
# Out:
# The correlation between Source Port and Anomaly Scores is: 0.004826322109444829

# %%
datacleaner.cont_to_cat("Anomaly Scores","Attack Type")
# Out:
# Attack Type is not correlated with Anomaly Scores

# %%
datacleaner.cont_to_cat("Source Port","Attack Type")
# Out:
# Attack Type is not correlated with Source Port

# %%
datacleaner.cat_to_cat("Attack Type","Traffic Type")
# Out:
# Chi_square value: 2.79039041904871
# p value: 0.593492634744949
# degrees of freedom: 4
# Attack Type is not correlated with Traffic Type

# %%
datacleaner.col_cat_dist("Device Information")

# %% [markdown]
# The  Data Set Has no Correlating feilds meaning We cant make a model for prediction from it
